# %% [markdown]
# ## Heatmaps

# %% [markdown]
# - seaborn.heatmap(data,vmin=None,vmax=None,linewidths=0,linecolor='white',annot=True,)

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data)
plt.show()
# Out:
# The data to be plotted:
#
# [[35 52 67 99 94 21 96 10 86 21]
#  [55 80 70 25 66 18 75 36 96 17]
#  [55 29 95 75 90 45 90 74 78 58]
#  [79 17 48 81 43 57 87 59 50 81]
#  [27 93 54 48 34 31 37  4 38 96]
#  [68 99 17 60 92  1 31  9  6 54]
#  [99 80 20 59 70 81 48 87 11 69]
#  [77  6 28 12 46 84 38 57 35 34]
#  [ 1 56 75 68 92 38  3 35 95 19]
#  [23 29 20 55 75  4 29 77 84 61]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[26 21 24 12 81 47 98 76 40 13]
#  [49 95 57 62 66 21 12 53 74 45]
#  [32 33 16 91 30 95 60 28 52  5]
#  [12 39 98 50 38 19 68 48 84 79]
#  [22 36 38  2 97 43 73 37 47 82]
#  [41 55 35 40 90 20 43 87 57 27]
#  [87 91 97 40 23 78 92 19 25 45]
#  [ 8 79 78 89 40 85 59 17 68 79]
#  [20 57 36 57 58  8 56 73  7 23]
#  [20  8 61 12 20 96 18 44 88 64]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,vmin=30,vmax=70)
plt.show()
# Out:
# The data to be plotted:
#
# [[28  3  2 12 85 33 30 77 24 62]
#  [95 55 45 15 87  4 56  7 65 29]
#  [73 57 39 40 24 33 24 33 96 87]
#  [15 57 42 25 86  8 60 82  6 76]
#  [31 11 37 53 63 75 98 50 76 34]
#  [38 30 97 16 93 71 52 33  6  1]
#  [33 28 17 49 24 57 38 32 25 44]
#  [51 65 21 87 13  2 93 68 97  3]
#  [73 65 37 66  4 72 44 65 73 62]
#  [42 10  8 45 90 47 18 25 19 27]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,vmin=30,vmax=70,annot=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[14 24 55 20 59 95 96 84 78 48]
#  [40 69 61 42 43 13 29 48 91 42]
#  [ 1 57 99 70 62 16 61 60 23 23]
#  [63 43 44 18 52 94 98 90  8 45]
#  [22 31 81 64 62 99 82 36 36 20]
#  [67  6  3 77 55 90 39 88 84 46]
#  [74 98 71 31 88 64 76  6  8 29]
#  [ 6 44 86 41 84  7 88 98 98 88]
#  [82 51  4 30 40 79 34 81  5 62]
#  [61 21 42 20 67 88 32 77 45 84]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,cmap="tab20")
plt.show()
# Out:
# The data to be plotted:
#
# [[ 6 85 95  1 63 18 19 58 15  2]
#  [42 43 55 57 61 59 83 91 76 64]
#  [67 16 86 98 58 99 50 21 56 43]
#  [ 9 41 92 38 31 61 95 92 43 89]
#  [97 44 71 12 15 54 62 71 61 80]
#  [65 26 67 52 45 48  1 21 73 95]
#  [85 48 77 89 60 57 22 99 22 25]
#  [64 52 72 41 67 40 26 68  6 16]
#  [ 4 48 54 90 93 61 70 35 56 66]
#  [36 18 33 47 79 68 80 80 80 94]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
hm=sns.heatmap(data,vmin=10,vmax=70,cmap='Pastel1',annot=True,linewidths=1,linecolor='black',cbar=False,xticklabels=False,
           yticklabels=False)
plt.show()
# Out:
# The data to be plotted:
#
# [[75 22 67 30 18 38 42 20 93 34]
#  [84 89 99 97 86 91 38 17 43 95]
#  [53 43 20 90 43 58 72 10 48 76]
#  [16 29 12  5 94 99 25 27 30 10]
#  [97 19  9  6 42 82 85 91 40 31]
#  [25  3 57 48 90 83 45 54 84 63]
#  [53 32 33 31 29 44 49 71 44 18]
#  [52 65 16 33 44 12 81 84 90 77]
#  [ 7 46 96 81 91  8 76 19 72 67]
#  [72 12 45 48 61 57 99 99 56 56]]

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.random((5,5)),columns=["a","b","c","d","e"])
print(df)
p1=sns.heatmap(df)
# Out:
#           a         b         c         d         e
# 0  0.262718  0.539143  0.937255  0.058304  0.923292
# 1  0.851257  0.802028  0.279381  0.486043  0.671706
# 2  0.769148  0.179083  0.502614  0.338806  0.954005
# 3  0.140592  0.792532  0.821911  0.965932  0.321960
# 4  0.924676  0.908977  0.616264  0.963889  0.211124

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(3,10))
print("The data to be plotted:\n")
print(data)
plt.figure(figsize=(15,5))
hm=sns.heatmap(data,vmin=10,vmax=70,cmap='Pastel1',annot=True,linewidths=2,linecolor='black',cbar=True,xticklabels=True,
           yticklabels=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[44 95 16  6  9 19 62 45 75 18]
#  [59 23 80 36 25 16 57  7  4  9]
#  [31 79 67 64 86 52 78 43 18 52]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('auto-mpg.csv')
sns.boxplot(y=df['mpg'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('auto-mpg.csv')
sns.boxplot(y=df['acceleration'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('auto-mpg.csv')
sns.boxplot(x=df['acceleration'],data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",hue="smoker",data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.boxplot(x="day",y="tip",data=df)
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('auto-mpg.csv')

df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce')
df=df.dropna(subset=['horsepower'])
plt.figure(figsize=(10,6))

sns.scatterplot(data=df,
                x='horsepower',   #horizontal axis
                y='mpg',hue='origin',
                style='origin',
                size='weight',
                palette='Set1')
plt.title("MPG ")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('auto-mpg.csv')

df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce')
df=df.dropna(subset=['horsepower'])
plt.figure(figsize=(10,6))

sns.scatterplot(data=df,
                x='horsepower',   #horizontal axis
                y='mpg')
plt.title("MPG ")
plt.tight_layout()
plt.show()
