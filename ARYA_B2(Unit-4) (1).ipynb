# %% [markdown]
# # Regression-Model Training & Evaluation

# %% [markdown]
# - Simple linear Regression
# - Multiple Linear Regression
# - Polynomial Regression

# %% [markdown]
# ## Evalution using
# -  R-squared -R^2 Score
# -  MAE(Mean Absolute Error)
# -  MSE(Mean Squared Error)

# %% [markdown]
# # Linear Regression
# - Statistical Method used to model the relationship between a dependent variable and one or more independent variable
# - The goal of LR is to find the best fitting line that describes the relationship between the variables.

# %%
import pandas as pd
df=pd.read_csv('test.csv')
df
# Out:
#      x   y
# 0   15  49
# 1   23  63
# 2   18  58
# 3   23  60
# 4   24  58
# 5   22  61
# 6   22  60
# 7   19  63
# 8   19  60
# 9   16  52
# 10  24  62
# 11  11  30
# 12  24  59
# 13  16  49
# 14  23  68

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       15 non-null     int64
#  1   y       15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes

# %%
df.isna().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
df.describe()
# Out:
#                x          y
# count  15.000000  15.000000
# mean   19.933333  56.800000
# std     4.026105   9.056963
# min    11.000000  30.000000
# 25%    17.000000  55.000000
# 50%    22.000000  60.000000
# 75%    23.000000  61.500000
# max    24.000000  68.000000

# %% [markdown]
# - y always Series
# - x should be DataFrame

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(x)
# Out:
#      x
# 0   15
# 1   23
# 2   18
# 3   23
# 4   24
# 5   22
# 6   22
# 7   19
# 8   19
# 9   16
# 10  24
# 11  11
# 12  24
# 13  16
# 14  23

# %%
print(y)
# Out:
# 0     49
# 1     63
# 2     58
# 3     60
# 4     58
# 5     61
# 6     60
# 7     63
# 8     60
# 9     52
# 10    62
# 11    30
# 12    59
# 13    49
# 14    68
# Name: y, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (15, 1)
# (15,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (13, 1)
# (13,)
# (2, 1)
# (2,)
#     x
# 3  23
# 7  19
# 3    60
# 7    63
# Name: y, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [62.41322902 54.56827881]

# %%
diff=pd.DataFrame({'Actual':y_test,'Predicted':ypred})
diff
# Out:
#    Actual  Predicted
# 3      60  62.413229
# 7      63  54.568279

# %%
print("coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# coefficient: [1.8939483]
# Intercept: 19.047297297297284

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
ypred=lr.predict(x)
print(ypred)
# Out:
# [47.45652174 62.60810811 53.13836663 62.60810811 64.5020564  60.71415981
#  60.71415981 55.03231492 55.03231492 49.35047004 64.5020564  39.88072855
#  64.5020564  49.35047004 62.60810811]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
# Out:
# MAE: 3.7412847630238946
# MSE: 22.292068155111636

# %%
# Second method
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
# Out:
# MAE: 3.7412847630238946
# MSE: 22.292068155111636

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
ypred=lr.predict([[18]])
print(ypred)
# Out:
# [53.13836663]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
print("R2 score:",metrics.r2_score(y,ypred))
# Out:
# MAE: 3.7412847630238946
# MSE: 22.292068155111636
# R2 score: 0.7088287858527738

# %%
# 15/4/2026

# %%
import pandas as pd
data={"hours_studied":[1,2,3,4,5,6,7],
"exam_score":[50,55,65,70,75,80,85]}
df=pd.DataFrame(data)
df
# Out:
#    hours_studied  exam_score
# 0              1          50
# 1              2          55
# 2              3          65
# 3              4          70
# 4              5          75
# 5              6          80
# 6              7          85

# %%
# x=np.array([1],[2],[3],[4],[5],[6],[7])
# y=np.array([50,55,65,70,75,80,85])

# %%
hours_studied=df.iloc[:,0:1]
exam_score=df.iloc[:,-1]

# %%
# Second Method for iloc and loc
# x=df[['hours_studied']]
# y=df['exam_score']

# %%
print(type(hours_studied))
print(type(exam_score))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(hours_studied.shape)
print(exam_score.shape)
# Out:
# (7, 1)
# (7,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(hours_studied,exam_score)
ypred=lr.predict(hours_studied)
print(ypred)
# Out:
# [50.89285714 56.78571429 62.67857143 68.57142857 74.46428571 80.35714286
#  86.25      ]

# %%
diff=pd.DataFrame({'Actual':exam_score,'Predicted':ypred})
diff
# Out:
#    Actual  Predicted
# 0      50  50.892857
# 1      55  56.785714
# 2      65  62.678571
# 3      70  68.571429
# 4      75  74.464286
# 5      80  80.357143
# 6      85  86.250000

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(exam_score,ypred))
print("MSE:",metrics.mean_squared_error(exam_score,ypred))
print("R2 score:",metrics.r2_score(exam_score,ypred))
# Out:
# MAE: 1.2244897959183672
# MSE: 1.9132653061224514
# R2 score: 0.9864130434782609

# %%
import matplotlib.pyplot as plt
plt.scatter(hours_studied,exam_score,color='blue',label='Actual scores')
plt.plot(hours_studied,ypred,color='red',label='Predicted Score')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title("Linear Regression")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('Book1.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
cgpa=df.iloc[:,0:1]
package=df.iloc[:,-1]

# %%
print(type(cgpa))
print(type(package))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(cgpa.shape)
print(package.shape)
# Out:
# (200, 1)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(cgpa,package,test_size=0.1,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (180, 1)
# (180,)
# (20, 1)
# (20,)
#      cgpa
# 58   6.92
# 40   9.38
# 34   7.34
# 102  5.13
# 184  7.88
# 198  7.63
# 95   6.63
# 4    6.94
# 29   7.15
# 168  8.65
# 171  8.01
# 18   6.94
# 11   6.61
# 89   6.42
# 110  8.18
# 118  7.40
# 159  8.71
# 35   6.87
# 136  5.64
# 59   7.56
# 58     3.09
# 40     4.02
# 34     3.42
# 102    1.37
# 184    3.14
# 198    3.96
# 95     2.79
# 4      3.57
# 29     3.49
# 168    3.52
# 171    3.76
# 18     2.98
# 11     2.60
# 89     2.72
# 110    3.76
# 118    2.88
# 159    4.08
# 35     2.87
# 136    2.10
# 59     3.31
# Name: package, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [2.95599947 4.35419203 3.19471527 1.93861546 3.50163559 3.35954285
#  2.79117189 2.96736689 3.08672479 3.93928123 3.57552382 2.96736689
#  2.77980448 2.67181399 3.67214688 3.22881753 3.97338349 2.92758092
#  2.22848465 3.31975689]

# %%
diff=pd.DataFrame({'Actual':y_test,'Predicted':ypred})
diff
# Out:
#      Actual  Predicted
# 58     3.09   2.955999
# 40     4.02   4.354192
# 34     3.42   3.194715
# 102    1.37   1.938615
# 184    3.14   3.501636
# 198    3.96   3.359543
# 95     2.79   2.791172
# 4      3.57   2.967367
# 29     3.49   3.086725
# 168    3.52   3.939281
# 171    3.76   3.575524
# 18     2.98   2.967367
# 11     2.60   2.779804
# 89     2.72   2.671814
# 110    3.76   3.672147
# 118    2.88   3.228818
# 159    4.08   3.973383
# 35     2.87   2.927581
# 136    2.10   2.228485
# 59     3.31   3.319757

# %%
print("coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# coefficient: [0.57425647]
# Intercept: -1.02700693745421

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))
# Out:
# MAE: 0.2407378157739672
# MSE: 0.09630812755183496
# R2 score: 0.7763411228752372

# %%
import matplotlib.pyplot as plt
plt.scatter(cgpa,package,color='blue',label='Actual scores')
plt.plot(package,ypred,color='red',label='Predicted Score')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.title("Linear Regression")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.scatter(cgpa,package,color='blue',label='Actual scores')
# ----> 3 plt.plot(package,ypred,color='red',label='Predicted Score')
#       4 plt.xlabel('cgpa')
#       5 plt.ylabel('package')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
d={}
for i in range(1,43):
    x_train,x_test,y_train,y_test=train_test_split(cgpa,package,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    ypred=lr.predict(x_test)
    d[i]=metrics.mean_absolute_error(y_test,ypred)
print(d)
# Out:
# {1: 0.29931188593316804, 2: 0.2884710931878175, 3: 0.310017871705637, 4: 0.27158297198220466, 5: 0.247306509791144, 6: 0.2602842528502706, 7: 0.3121829894800077, 8: 0.275653940756864, 9: 0.26247351451254086, 10: 0.2813149220232319, 11: 0.2860819180981433, 12: 0.2897281416313393, 13: 0.23499691146293503, 14: 0.2888891132014191, 15: 0.3103679805875928, 16: 0.279274096404684, 17: 0.24462502749846293, 18: 0.26615074687223644, 19: 0.18405380979816172, 20: 0.2969277139361391, 21: 0.236542679238719, 22: 0.2650980270523437, 23: 0.2650147048100542, 24: 0.26043386186698425, 25: 0.24784164138700185, 26: 0.22859395406310262, 27: 0.2774090254076157, 28: 0.26364229151896607, 29: 0.29545323943572077, 30: 0.29211827403569923, 31: 0.2465496367140863, 32: 0.24337661770042826, 33: 0.29030039318213663, 34: 0.273889690332112, 35: 0.25247281333484456, 36: 0.30824856143671253, 37: 0.26487607638630767, 38: 0.22341623830601928, 39: 0.221340974451211, 40: 0.24999051829818955, 41: 0.2673718686120335, 42: 0.231
# ...

# %%
import seaborn as sns
sns.regplot(data=df,x='cgpa',y='package')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
ypred=lr.predict([[8.5]])
print(ypred)
# Out:
# [3.85417308]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
df=pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.drop('Car_Name',axis=1,inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df['Age']=2026-df['Year']

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   12
# ...

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   12
# 1         Manual      0   13
# 2         Manual      0    9
# 3         Manual      0   15
# ...

# %%
df.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Age'],
#       dtype='object')

# %%
df=pd.get_dummies(data=df,drop_first=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   12             False
# 1             4.75           9.54       43000      0   13              True
# 2             7.25           9.85        6900      0    9             False
# 3             2.85           4.15        5200      0   15             False
# 4             4.60           6.87       42450      0   12              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0   10              True
# 297           4.00           5.90       60000      0   11             False
# 298           3.35          11.00       87934      0   17             False
# 299          11.50          12.50        9000      0    9              True
# 300           5.30           5.90        5464      0   10             False
#
# ...

# %%
x=df.drop('Selling_Price',axis=1)   #//df.iloc[:,1:],df[[ ]]
y=df['Selling_Price']

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(x.shape)
print(y.shape)
# Out:
# (301, 8)
# (301,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (240, 8)
# (240,)
# (61, 8)
# (61,)
#      Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 285          8.500       15059      0   10             False
# 248          4.600       30000      0   13             False
# 150          0.826        6000      0   15             False
# 217          4.430       15000      0   10             False
# 107          1.500       15000      0   13             False
# ..             ...         ...    ...  ...               ...
# 62          35.960       78000      0   12              True
# 154          0.880        8000      0   12             False
# 218          9.400       45078      0   12             False
# 286          7.900       28569      0   10             False
# 186          0.520       22000      0   16             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 285              True                   False                False
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [ 7.86273200e+00  2.96828691e+00 -5.90305107e-01  4.21335952e+00
#   4.83175534e-01  5.82053813e+00  1.95679784e+00  2.55809661e+00
#   7.70870833e+00  9.78692192e-01  8.13484343e+00  3.51207180e+00
#   4.90669281e+00  4.63905587e+00 -2.15886643e+00  3.13874624e+00
#   7.98256903e+00  6.75937638e+00  6.90426580e+00  8.01440587e+00
#   4.31168610e+00  4.00336757e+00  1.13040883e+01  8.07939189e+00
#   9.54399823e+00  3.52133877e+00  3.80609808e+00  1.06074722e+00
#  -6.01732475e-01 -6.19712043e-01  1.32818516e-03 -1.28500691e+00
#   4.28533553e+00  2.06769487e+01  1.87563232e+01  4.27292100e+00
#   3.48602852e+00  1.66739677e+00 -4.38707073e-02  5.78536030e+00
#   8.03940428e+00  9.88367483e+00  4.09684249e-01  6.07997517e+00
#   5.88038915e+00  4.32745252e+00  7.37534505e+00  5.86171335e+00
#   8.21129880e+00  1.65455816e+00  3.83033706e+00  1.75047060e+00
#   2.51406796e+00  4.20404709e+00  1.48991546e+00 -3.44185843e+00
# ...

# %%
diff=pd.DataFrame({'Actual':y_test,'Predicted':ypred})
diff
# Out:
#      Actual  Predicted
# 285    7.40   7.862732
# 248    4.00   2.968287
# 150    0.50  -0.590305
# 217    3.15   4.213360
# 107    1.25   0.483176
# ..      ...        ...
# 62    18.75  20.480622
# 154    0.50   0.662504
# 218    6.45   5.400274
# 286    5.65   5.658562
# 186    0.25   0.647876
#
# [61 rows x 2 columns]

# %%
print("coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# coefficient: [ 4.37233976e-01 -5.30613944e-06  3.45912849e-01 -4.13270098e-01
#   2.23050770e+00  4.58549217e-01 -1.20927814e+00 -1.87014327e+00]
# Intercept: 7.900300130264206

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))
# Out:
# MAE: 1.0998575552990955
# MSE: 2.9823848618597513
# R2 score: 0.8625260513315252

# %%
ypred=lr.predict([[7.5,25000,0,10,0,0,1,1]])
print(ypred)
# Out:
# [3.83477907]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# 17/4/2026

# %%
import pandas as pd
df=pd.read_csv('Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
x=df.drop(['Unnamed: 0','Sales'],axis=1)   
y=df['Sales']

# %%
print(x)
print(y)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (160, 3)
# (160,)
# (40, 3)
# (40,)
#         TV  Radio  Newspaper
# 58   210.8   49.6       37.7
# 40   202.5   22.3       31.6
# 34    95.7    1.4        7.4
# 102  280.2   10.1       21.4
# 184  253.8   21.3       30.0
# 198  283.6   42.0       66.2
# 95   163.3   31.6       52.9
# 4    180.8   10.8       58.4
# 29    70.6   16.0       40.8
# 168  215.4   23.6       57.6
# 171  164.5   20.9       47.4
# 18    69.2   20.5       18.3
# 11   214.7   24.0        4.0
# 89   109.8   47.8       51.4
# 110  225.8    8.2       56.5
# 118  125.7   36.9       79.2
# 159  131.7   18.4       34.6
# 35   290.7    4.1        8.5
# 136   25.6   39.0        9.3
# 59   210.7   29.5        9.3
# 51   100.4    9.6        3.6
# 16    67.8   36.6      114.0
# 44    25.1   25.7       43.3
# 94   107.4   14.0       10.9
# 31   112.9   17.4       38.6
# 162  188.4   18.1       25.6
# 38    43.1   26.7       35.1
# 28   248.8   27.1       22.9
# 193  166.8   42.0        3.6
# 27   240.1   16.7       22.9
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [21.73577184 16.45693776  7.65993185 17.89202679 18.67730671 23.86271904
#  16.33623628 13.45649226  9.177296   17.36056228 14.4677995   9.85697601
#  17.26057027 16.71866935 15.09530285 15.58923732 12.45188167 17.27925151
#  11.0944114  18.06889853  9.33433055 12.91345761  8.7842804  10.46670654
#  11.40303174 15.03104665  9.78479388 19.46028647 18.22954934 17.1958903
#  21.60304218 14.71901407 16.29205532 12.36432281 19.98831261 15.37556411
#  13.96678297 10.06809496 20.97197274  7.45877832]

# %%
diff=pd.DataFrame({'Actual':y_test,'Predicted':ypred})
diff
# Out:
#      Actual  Predicted
# 58     23.8  21.735772
# 40     16.6  16.456938
# 34      9.5   7.659932
# 102    14.8  17.892027
# 184    17.6  18.677307
# 198    25.5  23.862719
# 95     16.9  16.336236
# 4      12.9  13.456492
# 29     10.5   9.177296
# 168    17.1  17.360562
# 171    14.5  14.467799
# 18     11.3   9.856976
# 11     17.4  17.260570
# 89     16.7  16.718669
# 110    13.4  15.095303
# 118    15.9  15.589237
# 159    12.9  12.451882
# 35     12.8  17.279252
# 136     9.5  11.094411
# 59     18.4  18.068899
# 51     10.7   9.334331
# 16     12.5  12.913458
# 44      8.5   8.784280
# 94     11.5  10.466707
# 31     11.9  11.403032
# 162    14.9  15.031047
# 38     10.1   9.784794
# 28     18.9  19.460286
# 193    19.6  18.229549
# 27     15.9  17.195890
# 47     23.2  21.603042
# 165    11.9  14.719014
# 194    17.3  16.292055
# 177    11.7  12.364323
# 176    20.2  19.988313
# 97     15.5  15.375564
# 174    11.5  13.966783
# 73     11.0  10.068095
# 69     22.3  20.971973
# ...

# %%
print("coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# coefficient: [0.0468431  0.17854434 0.00258619]
# Intercept: 2.9079470208164295

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))
# Out:
# MAE: 1.0402154012924718
# MSE: 1.9918855518287906
# R2 score: 0.8927605914615384

# %%
import pandas as pd
df=pd.read_csv('FuelConsumptionCo2.csv')
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.drop(columns=['VEHICLECLASS',"MAKE","TRANSMISSION","MODEL"],axis=1,inplace=True)

# %%
df
# Out:
#       MODELYEAR  ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0          2014         2.0          4        Z                   9.9
# 1          2014         2.4          4        Z                  11.2
# 2          2014         1.5          4        Z                   6.0
# 3          2014         3.5          6        Z                  12.7
# 4          2014         3.5          6        Z                  12.1
# ...         ...         ...        ...      ...                   ...
# 1062       2014         3.0          6        X                  13.4
# 1063       2014         3.2          6        X                  13.2
# 1064       2014         3.0          6        X                  13.4
# 1065       2014         3.2          6        X                  12.9
# 1066       2014         3.2          6        X                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# ...

# %%
df=pd.get_dummies(data=df,drop_first=True)

# %%
df
# Out:
#       MODELYEAR  ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# 0          2014         2.0          4                   9.9
# 1          2014         2.4          4                  11.2
# 2          2014         1.5          4                   6.0
# 3          2014         3.5          6                  12.7
# 4          2014         3.5          6                  12.1
# ...         ...         ...        ...                   ...
# 1062       2014         3.0          6                  13.4
# 1063       2014         3.2          6                  13.2
# 1064       2014         3.0          6                  13.4
# 1065       2014         3.2          6                  12.9
# 1066       2014         3.2          6                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                     6.7                   8.5                        33
# 1                     7.7                   9.6                        29
# ...

# %%
x=df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']]
y=df['CO2EMISSIONS']

# %%
print(x.shape)
print(y.shape)
# Out:
# (1067, 3)
# (1067,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (853, 3)
# (853,)
# (214, 3)
# (214,)
#      ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB
# 133         3.0          6                  11.9
# 340         1.4          4                   8.7
# 948         2.0          4                   8.5
# 704         2.0          4                   7.0
# 661         4.6          8                  13.9
# ..          ...        ...                   ...
# 961         3.6          6                  13.1
# 523         1.6          4                   8.0
# 884         3.8          6                  11.9
# 8           3.7          6                  11.6
# 415         2.0          4                   5.5
#
# [214 rows x 3 columns]
# 133    274
# 340    200
# 948    196
# 704    161
# 661    320
#       ...
# 961    301
# 523    184
# 884    274
# 8      267
# 415    126
# Name: CO2EMISSIONS, Length: 214, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [257.0729753  193.62675365 198.61947156 184.0315625  308.84886971
#  222.06199356 185.00408977 193.38929893 234.70484808 197.40948958
#  217.83256226 260.96308439 200.32707139 363.64971908 200.51083953
#  192.73062136 193.99428993 314.31649706 261.88192508 215.88750772
#  440.76775066 216.07127586 254.46924319 258.96434327 279.75495223
#  239.56748443 162.03372438 288.13465573 187.18659903 231.68539877
#  229.84221172 367.53982816 246.32148875 360.70666476 285.37813365
#  315.9704103  351.66277803 181.16766727 341.17972436 257.62427972
#  239.56748443 373.66062742 215.15243517 257.20305686 256.41429773
#  201.53705338 189.73664457 161.53335371 181.11398069 250.02782969
#  189.13165357 336.15602827 329.4839246  344.85508713 211.26232608
#  269.05715225 208.29105769 289.16086958 263.22198863 185.24154449
#  209.07981683 238.80693936 209.31727154 194.72936248 215.15243517
#  193.38929893 259.33187954 253.31294778 204.45463519 209.55472626
# ...

# %%
lr.coef_

# %%
diff=pd.DataFrame({'Actual':y_test,'Predicted':ypred})
diff
# Out:
#      Actual   Predicted
# 133     274  257.072975
# 340     200  193.626754
# 948     196  198.619472
# 704     161  184.031563
# 661     320  308.848870
# ..      ...         ...
# 961     301  275.681075
# 523     184  189.131654
# 884     274  266.323339
# 8       267  262.249461
# 415     126  169.443653
#
# [214 rows x 2 columns]

# %%
print("coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# coefficient: [11.56295409  6.91231122  9.72527271]
# Intercept: 65.17950048137254

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))
# Out:
# MAE: 16.64682799882323
# MSE: 546.2591396903438
# R2 score: 0.8653355812644816

# %%
x=df.drop(columns=['MODELYEAR','FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY','FUELTYPE_E','FUELTYPE_X','FUELTYPE_Z'],axis=1,inplace=True)
y=df['CO2EMISSIONS']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))

# %%
import pandas as pd
df=pd.read_csv('polylinearregression.csv')
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
x=df.iloc[:,1:2]
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
ypred=lr.predict(x)
print(ypred)
# Out:
# [-0.05086667 -0.00402667  0.04281333  0.08965333  0.13649333  0.18333333]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
print("R2 score:",metrics.r2_score(y,ypred))
# Out:
# MAE: 0.047653333333333346
# MSE: 0.002870267555555557
# R2 score: 0.690349972603981

# %%
import seaborn as sns
sns.regplot(data=df,x='Temperature',y='Pressure')
# Out:
# <Axes: xlabel='Temperature', ylabel='Pressure'>

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.00e+00 0.00e+00 0.00e+00 0.00e+00]
#  [1.00e+00 2.00e+01 4.00e+02 8.00e+03]
#  [1.00e+00 4.00e+01 1.60e+03 6.40e+04]
#  [1.00e+00 6.00e+01 3.60e+03 2.16e+05]
#  [1.00e+00 8.00e+01 6.40e+03 5.12e+05]
#  [1.00e+00 1.00e+02 1.00e+04 1.00e+06]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
ypred=lr.predict(x_poly)
print(ypred)
# Out:
# [-0.00198889  0.00724444  0.00371111  0.02248889  0.09865556  0.26728889]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
print("R2 score:",metrics.r2_score(y,ypred))
# Out:
# MAE: 0.004899999999994181
# MSE: 3.0875185185185205e-05
# R2 score: 0.9966691251761722

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue')
plt.plot(x,ypred,color='red')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=5)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [1.0000e+00 2.0000e+01 4.0000e+02 8.0000e+03 1.6000e+05 3.2000e+06]
#  [1.0000e+00 4.0000e+01 1.6000e+03 6.4000e+04 2.5600e+06 1.0240e+08]
#  [1.0000e+00 6.0000e+01 3.6000e+03 2.1600e+05 1.2960e+07 7.7760e+08]
#  [1.0000e+00 8.0000e+01 6.4000e+03 5.1200e+05 4.0960e+07 3.2768e+09]
#  [1.0000e+00 1.0000e+02 1.0000e+04 1.0000e+06 1.0000e+08 1.0000e+10]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
ypred=lr.predict(x_poly)
print(ypred)
# Out:
# [2.00000474e-04 1.20000008e-03 5.99999994e-03 3.00000000e-02
#  8.99999999e-02 2.70000000e-01]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
print("R2 score:",metrics.r2_score(y,ypred))
# Out:
# MAE: 1.9746440743300393e-10
# MSE: 6.913810950560085e-20
# R2 score: 1.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue')
plt.plot(x,ypred,color='red')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('car_data.csv')
df
# Out:
#    Horsepower  Weight  MPG
# 0         130    3504   18
# 1         165    3693   15
# 2         150    3436   18
# 3         140    3433   16
# 4         198    4341   14
# 5         220    4354   12
# 6          95    2372   25
# 7          88    2130   27
# 8          98    2228   24

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
print(x)
print(y)
# Out:
#    Horsepower  Weight
# 0         130    3504
# 1         165    3693
# 2         150    3436
# 3         140    3433
# 4         198    4341
# 5         220    4354
# 6          95    2372
# 7          88    2130
# 8          98    2228
# 0    18
# 1    15
# 2    18
# 3    16
# 4    14
# 5    12
# 6    25
# 7    27
# 8    24
# Name: MPG, dtype: int64

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.00000000e+00 1.30000000e+02 3.50400000e+03 1.69000000e+04
#   4.55520000e+05 1.22780160e+07 2.19700000e+06 5.92176000e+07
#   1.59614208e+09 4.30221681e+10]
#  [1.00000000e+00 1.65000000e+02 3.69300000e+03 2.72250000e+04
#   6.09345000e+05 1.36382490e+07 4.49212500e+06 1.00541925e+08
#   2.25031108e+09 5.03660536e+10]
#  [1.00000000e+00 1.50000000e+02 3.43600000e+03 2.25000000e+04
#   5.15400000e+05 1.18060960e+07 3.37500000e+06 7.73100000e+07
#   1.77091440e+09 4.05657459e+10]
#  [1.00000000e+00 1.40000000e+02 3.43300000e+03 1.96000000e+04
#   4.80620000e+05 1.17854890e+07 2.74400000e+06 6.72868000e+07
#   1.64996846e+09 4.04595837e+10]
#  [1.00000000e+00 1.98000000e+02 4.34100000e+03 3.92040000e+04
#   8.59518000e+05 1.88442810e+07 7.76239200e+06 1.70184564e+08
#   3.73116764e+09 8.18030238e+10]
#  [1.00000000e+00 2.20000000e+02 4.35400000e+03 4.84000000e+04
#   9.57880000e+05 1.89573160e+07 1.06480000e+07 2.10733600e+08
#   4.17060952e+09 8.25401539e+10]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_poly,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_test)
print(y_test)
# Out:
# (7, 10)
# (7,)
# (2, 10)
# (2,)
# [[1.00000000e+00 9.80000000e+01 2.22800000e+03 9.60400000e+03
#   2.18344000e+05 4.96398400e+06 9.41192000e+05 2.13977120e+07
#   4.86470432e+08 1.10597564e+10]
#  [1.00000000e+00 1.50000000e+02 3.43600000e+03 2.25000000e+04
#   5.15400000e+05 1.18060960e+07 3.37500000e+06 7.73100000e+07
#   1.77091440e+09 4.05657459e+10]]
# 8    24
# 2    18
# Name: MPG, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(ypred)
# Out:
# [25.92139147 16.15742828]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,ypred))
print("MSE:",metrics.mean_squared_error(y_test,ypred))
print("R2 score:",metrics.r2_score(y_test,ypred))
# Out:
# MAE: 1.8819815956242962
# MSE: 3.543407864452031
# R2 score: 0.6062880150608854

# %%
# Task

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]

# %%
x=pd.DataFrame(x)
y=pd.Series(y)

# %%
print(x)
print(y)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# 0      1
# 1      8
# 2     27
# 3     64
# 4    125
# dtype: int64

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[ 1.  1.  1.]
#  [ 1.  2.  4.]
#  [ 1.  3.  9.]
#  [ 1.  4. 16.]
#  [ 1.  5. 25.]]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
ypred=lr.predict(x_poly)
print(ypred)
# Out:
# [  2.2   5.6  27.   66.4 123.8]

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y,ypred))
print("MSE:",metrics.mean_squared_error(y,ypred))
print("R2 score:",metrics.r2_score(y,ypred))
# Out:
# MAE: 1.4399999999999882
# MSE: 2.8800000000000043
# R2 score: 0.998614051973051

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue')
plt.plot(x,ypred,color='red')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,8,27,64,125]
